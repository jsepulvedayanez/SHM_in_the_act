# %% [markdown]
# # Enrichment analysis via active subnetwork (pathfindR)

# %%
library(pathfindR)
library('KEGGREST')
library(tidyverse)
# Out:
# Warning message:
# “package ‘tidyverse’ was built under R version 4.1.2”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   1.0.1
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.3.0      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# Warning message:
# “package ‘ggplot2’ was built under R version 4.1.2”
# Warning message:
# “package ‘tibble’ was built under R version 4.1.2”
# Warning message:
# “package ‘readr’ was built under R version 4.1.2”
# Warning message:
# “package ‘purrr’ was built under R version 4.1.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.1.2”
# Warning message:
# “package ‘stringr’ was built under R version 4.1.2”
# Warning message:
# “package ‘forcats’ was built under R version 4.1.2”
# ...

# %%
DE_scSHM <- read.csv("output/DE_scSHM.csv")

# %%
output_df <- run_pathfindR(DE_scSHM %>% as.data.frame() %>% filter(!is.na(padj)) %>% dplyr::select(rowname,log2FoldChange,padj), output_dir = "pathFindR")
# Out:
# There is already a directory named "pathFindR".
# Writing the result to "pathFindR(5)" not to overwrite any previous results.
#
# ## Testing input
#
# The input looks OK
#
# ## Processing input. Converting gene symbols,
#           if necessary (and if human gene symbols provided)
#
# Number of genes provided in input: 2858
#
# Number of genes in input after p-value filtering: 786
#
#
#
# Could not find any interactions for 4 (0.51%) genes in the PIN
#
# Final number of genes in input: 782
#
# ## Performing Active Subnetwork Search and Enrichment
#
# ## Processing the enrichment results over all iterations
#
# ## Annotating involved genes and visualizing enriched terms
# ...
#
#   |======================================================================| 100%
# Saving colored pathway diagrams of 10 KEGG pathways
#
#   |======================================================================| 100%
# By default, the top 10 KEGG pathways are visualized
# ...
