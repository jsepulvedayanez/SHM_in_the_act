# %% [markdown]
# # Diferential Expression (DE) analysis

# %% [markdown]
# Code from: https://git.lumc.nl/hem/FL_10X_2/-/blob/master/410_S144_case/S144_analysis.Rmd
#
# - title: "Focus on S144 NliG"
# - author:
#   - name: C.A.M. van Bergen
#   - affiliation: Leiden University Medical Center

# %%
# load packages and user-defined functions
options(warn=-1)
suppressPackageStartupMessages( library( DESeq2 ) )
suppressPackageStartupMessages( library( BiocParallel ) )
library(tidyverse)
library(data.table)
library("AnnotationDbi")
library("org.Hs.eg.db")
library(pathview)
library(gage)
library(gageData)
data(kegg.sets.hs)
data(sigmet.idx.hs)
kegg.sets.hs = kegg.sets.hs[sigmet.idx.hs]
library(scran)
library('glmGamPoi')
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   1.0.1
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.3.0      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::collapse()   masks IRanges::collapse()
# ✖ dplyr::combine()    masks Biobase::combine(), BiocGenerics::combine()
# ✖ dplyr::count()      masks matrixStats::count()
# ✖ dplyr::desc()       masks IRanges::desc()
# ✖ tidyr::expand()     masks S4Vectors::expand()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::first()      masks S4Vectors::first()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ ggplot2::Position() masks BiocGenerics::Position(), base::Position()
# ✖ purrr::reduce()     masks GenomicRanges::reduce(), IRanges::reduce()
# ✖ dplyr::rename()     masks S4Vectors::rename()
# ✖ dplyr::slice()      masks IRanges::slice()
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     shift
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
#
# Attaching package: ‘AnnotationDbi’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
#
#
# ##############################################################################
# Pathview is an open source software package distributed under GNU General
# Public License version 3 (GPLv3). Details of GPLv3 is available at
# http://www.gnu.org/licenses/gpl-3.0.html. Particullary, users are required to
# formally cite the original Pathview paper (not just mention it) in publications
# or products. For details, do citation("pathview") within R.
#
# The pathview downloads and uses KEGG data. Non-academic uses may require a KEGG
# license agreement (details at http://www.kegg.jp/kegg/legal.html).
# ##############################################################################
#
#
#
# Loading required package: SingleCellExperiment
#
# Loading required package: scuttle

# %%
suppressMessages(source("code/functions.R"))

# %%
#Load input data (raw data, all cells)

df_seq <- Sys.glob("input/output_shm_20220819/*/consensus/*/*.csv") %>%
  purrr::map_dfr(function(x) {
    readr::read_csv(x, col_types = "cciccici", progress = FALSE) %>%
      dplyr::mutate(subject = gsub("^.*/|.csv*$", "", x)) %>%
      filter(ref_vdj_coverage == '1.0')
  })

# %%
trully_negative <- read.csv("output/trully_negative_cells.csv")

# %%
str(trully_negative)
# Out:
# 'data.frame':	3417 obs. of  2 variables:
#  $ source: chr  "K4B" "K4B" "K4B" "K4B" ...
#  $ cell  : chr  "AAACCTGTCACGAAGG" "AAACGGGAGTGGCACA" "AAACGGGGTCTAGCGC" "AAAGCAAGTACTTAGC" ...

# %%
# seurat object
FL.integrated <- readRDS("output/K45678_integrated.rds")

# %%
#barcodes of cells group 2
cells1 <- read.csv("output/df_summary_K45678_v5.csv") %>% mutate(experiment=str_extract(subject, "^.{2}")) %>%
          filter(subject %like% "K7B") %>% mutate(cell_seurat=case_when(experiment == "K7" ~ paste0(cell,"-1_4"),
                                                                                             TRUE ~ "NA"
                                                                                                 )) %>%
        pull(cell_seurat) %>% unique()

#barcodes of cells group 1
# cells2 <- df_seq %>% filter(cell %in% trully_negative$cell) %>% mutate(experiment=str_extract(subject, "^.{2}")) %>% mutate(cell_seurat=case_when(experiment == "K4" ~ paste0(cell,"-1_1"),
#                                                                                              experiment == "K5" ~ paste0(cell,"-1_2"),
#                                                                                              experiment == "K6" ~ paste0(cell,"-1_3"),
#                                                                                              experiment == "K7" ~ paste0(cell,"-1_4"),
#                                                                                              experiment == "K8" ~ paste0(cell,"-1_5"),
#                                                                                              TRUE ~ "NA"
#                                                                                                  )) %>% filter(!cell_seurat %in% cells1) %>%
#            pull(cell_seurat) %>% unique() %>% sample(2000)

cells2 <- trully_negative %>% mutate(cell_seurat=case_when(source == "K4B" ~ paste0(cell,"-1_1"),
                                                                                             source == "K5B" ~ paste0(cell,"-1_2"),
                                                                                             source == "K6B" ~ paste0(cell,"-1_3"),
                                                                                             source == "K7B" ~ paste0(cell,"-1_4"),
                                                                                             source == "K8B" ~ paste0(cell,"-1_5"),
                                                                                             TRUE ~ "NA"
                                                                                                 )) %>% 
           pull(cell_seurat) %>% unique() %>% sample(300)

# %%
cells1 %>% str()
cells2 %>% str()
# Out:
#  chr [1:88] "CAGCTAAAGTACGCGA-1_4" "GCTGCAGTCTTGTTTG-1_4" ...
#  chr [1:300] "GTCCTCATCTAACTGG-1_2" "CAAGATCAGTTTAGGA-1_1" ...

# %% [markdown]
# **The package DESeq2 provides methods to test for differential expression by use of negative binomial generalized linear models; the estimates of dispersion and logarithmic fold changes incorporate data-driven prior distributions.**
# - **Why un-normalized counts?**
# As input, the DESeq2 package expects count data as obtained, e.g., from RNA-seq or another high-throughput sequencing experiment, in the form of a matrix of integer values. The value in the i-th row and the j-th column of the matrix tells how many reads can be assigned to gene i in sample j. Analogously, for other types of assays, the rows of the matrix might correspond e.g. to binding regions (with ChIP-Seq) or peptide sequences (with quantitative mass spectrometry). We will list method for obtaining count matrices in sections below.
# The values in the matrix should be un-normalized counts or estimated counts of sequencing reads (for single-end RNA-seq) or fragments (for paired-end RNA-seq). The RNA-seq workflow describes multiple techniques for preparing such count matrices. It is important to provide count matrices as input for DESeq2’s statistical model (Love, Huber, and Anders 2014) to hold, as only the count values allow assessing the measurement precision correctly. The DESeq2 model internally corrects for library size, so transformed or normalized values such as counts scaled by library size should not be used as input.

# %%
DEgenes <-
  # function that performs DE gene analysis
  # s     = seurat object, corrected for zeroes
  # cell1 = barcodes of cells group 1
  # cell2 = barcodes of cells group 2
  # max   = max cells per group  
  function( sObject, cells1, cells2 ){
    # subset d for cell1 and cell2, for max cells
    d <-
      bind_rows(
        cells1 %>% 
          as.data.frame() %>% 
          mutate( group = 2 ),
        cells2 %>% 
          as.data.frame() %>% 
          mutate( group = 1 ) ) %>%
      column_to_rownames( var = "." ) %>% 
      mutate( group = factor( group, levels = c( 1, 2 ) ) )
    
    
    # extract count table and subset for cells in colData
    cts <-
      FL.integrated@assays$RNA@counts  %>%
      as.matrix()%>% #add step
      as.data.frame() %>%
      dplyr::select( rownames( d ) ) %>%
      rownames_to_column( var = "geneName" )
    
    # remove RPL, RPS and MT- genes
    cts <-
      cts %>% 
      filter( !geneName %like% "^RPL",
              !geneName %like% "^RPS",
              !geneName %like% "^IG[HKL][VMCG]",
              !geneName %like% "^MT-" ) %>% 
      column_to_rownames( var = "geneName" )
    
    # are colnames in cts similarly ordered as in colData?
    if( all( rownames( d ) == colnames( cts ) ) == FALSE ){
      cts <- cts[ , rownames( d ) ]
      all( rownames( d ) == colnames( cts ) ) }
    
    # create the DESeq2 object
    dds <-
      DESeqDataSetFromMatrix( countData = round(cts),
                              colData   = d,
                              design    = ~ group )
    
    # set test and reference
    dds$cluster <-
      relevel( dds$group, ref = "1" )
      
    
    # add genenames to the DESeq2 object
    mcols( dds ) <-
      DataFrame( mcols( dds ),
                 data.frame( gene = rownames( cts ) ) )
    
    # limit data to genes with total read count >= 1% of cell count in the data
    dds <-
      dds[ rowSums( counts( dds ) ) >= 0.01 * nrow( dds ) , ]
      
    #Estimate size factors
    dds <- estimateSizeFactors(dds, type="poscounts")
    scr <- computeSumFactors(dds)
    
    # use scran's sum factors:
    sizeFactors(dds) <- sizeFactors(scr)
    
    # run
    dds <-
      DESeq( dds,
             fitType = "glmGamPoi",
             parallel = FALSE, 
             test="LRT",
             reduced = ~ 1,
             useT=TRUE,
             minmu=1e-6,
             minReplicatesForReplace=Inf,
             BPPARAM = MulticoreParam( detectCores() ) )
    
    
    # collect results, specify coefficient
    res <-
      results( dds )
    
    # extract data from res, all genes
    DEgenes <- bind_cols( res@rownames,
                          res@listData$log2FoldChange,
                          res@listData$lfcSE,
                          res@listData$pval,
                          res@listData$padj ) %>%
      `colnames<-`( c( "rowname", "log2FoldChange", "lfcSE", "pval", "padj" ) )
    
    return( DEgenes)
  }

# %% [markdown]
# - if it dosen't work run cells again

# %%
DE_scSHM <- DEgenes(sObject, cells1, cells2)
# Out:
# converting counts to integer mode
#
# using pre-existing size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# using 'glmGamPoi' as fitType. If used in published research, please cite:
#     Ahlmann-Eltze, C., Huber, W. (2020) glmGamPoi: Fitting Gamma-Poisson
#     Generalized Linear Models on Single Cell Count Data. Bioinformatics.
#     https://doi.org/10.1093/bioinformatics/btaa1009
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# Fit reduced model
#
# Calculate quasi likelihood ratio
#
# Prepare results
#
# New names:
# • `` -> `...1`
# • `` -> `...2`
# • `` -> `...3`
# • `` -> `...4`
# • `` -> `...5`

# %%
# volcano plot
# input is table with DE genes
VolcanoPlot <-
  function( d ){
    ggplot( d %>%
              filter( !is.na( padj ) ),
            aes( x = log2FoldChange, y = -log10( padj ) ) ) +
      geom_point( size = 0.5) +
      geom_hline( yintercept = -log10( 0.05), linetype="dashed",  color = "grey" ) +
      geom_vline( xintercept = -0.5, linetype="dashed",  color = "grey", size = 0.5 ) +
      geom_vline( xintercept = 0.5, linetype="dashed",  color = "grey", size = 0.5 ) +
      ggrepel::geom_text_repel(
        data =  bind_rows( d %>%
                             filter( padj <= 0.05 ) %>% #!is.na( padj ) ) %>%
                             arrange( log2FoldChange )  %>%
                             dplyr::slice( 1:16 ),
                           d %>%
                             filter( padj <= 0.05 ) %>% #!is.na( padj ) ) %>%
                             arrange( desc( log2FoldChange ) ) %>%
                             dplyr::slice( 1:16 ),
                           d %>%
                             filter( padj <= 0.05 ) %>% #!is.na( padj ) ) %>%
                             arrange( padj ) %>%
                             dplyr::slice( 1:16 ) ) %>%
          # distinct on 2 variables to keep genes
          distinct( rowname, .keep_all = TRUE) %>%
          filter( !is.na( log2FoldChange ),
                  log2FoldChange < -0.5 | log2FoldChange > 0.5),
        aes( label = rowname ), color = "red", size = 3 ) }

VolcanoPlotFixedFrame <-
  function( d ){
    # remove padj = NA
    d <-
      filter( d, !is.na( padj ) )
    # maximize coordinates for better comparison
    if( min( d$log2FoldChange ) < -2.5 ){
      d[ which( d$log2FoldChange < - 2.5 ), "log2FoldChange" ] <-
        - 1 }
    if( max( d$log2FoldChange ) > 2.5 ){
      d[ which( d$log2FoldChange > 2.5 ), "log2FoldChange" ] <-
        1 }
    if( min( d$padj ) < 1e-80 ){
      d[ which( d$padj < 1e-80 ), "padj" ] <-
        1e-80 }
    
    ggplot( d,
            aes( x = log2FoldChange, y = -log10( padj ) ) ) +
      geom_point( size = 0.5) +
      xlim( c( -2.5, 2.5 ) ) +
      ylim( c( 1, -log10( 1e-80 ) ) ) +
      geom_point( data = d %>% 
                    filter( log2FoldChange > -.5 & log2FoldChange < .5 ),
                  aes(  x = log2FoldChange, y = -log10( padj ) ), size = 0.5, color = "grey" ) +
      geom_hline( yintercept = -log10( 0.05), linetype="dashed",  color = "grey" ) +
      geom_vline( xintercept = -0.5, linetype="dashed",  color = "grey", size = 0.5 ) +
      geom_vline( xintercept = 0.5, linetype="dashed",  color = "grey", size = 0.5 ) +
      ggrepel::geom_text_repel(
        data =  bind_rows( d %>%
                             filter( !is.na( padj ) ) %>%
                             arrange( log2FoldChange )  %>%
                             dplyr::slice( 1:25 ),
                           d %>%
                             filter( !is.na( padj ) ) %>%
                             arrange( desc( log2FoldChange ) ) %>%
                             dplyr::slice( 1:25 ),
                           d %>%
                             filter( !is.na( padj ) ) %>%
                             arrange( padj ) %>%
                             dplyr::slice( 1:25 ) ) %>%
          # distinct on 2 variables to keep genes
          distinct( rowname, .keep_all = TRUE) %>%
          filter( !is.na( log2FoldChange ),
                  log2FoldChange < -0.5 | log2FoldChange > 0.5),
        aes( label = rowname ), color = "red", size = 2.5, segment.size = 0.2 )
  }

# %%
td <- VolcanoPlot(DE_scSHM)
td
# Out:
# plot without title

# %%
fig_save(td , filename = ("figs/volcano_plot_S10000"), formats = c("pdf", "png"), width = 15, height =15, units = "cm", dpi = 320)

# %% [markdown]
# If within a row, all samples have zero counts, the baseMean column will be zero, and the log2 fold change estimates, p value and adjusted p value will all be set to NA.
# If a row contains a sample with an extreme count outlier then the p value and adjusted p value will be set to NA. These outlier counts are detected by Cook’s distance. Customization of this outlier filtering and description of functionality for replacement of outlier counts and refitting is described below
# If a row is filtered by automatic independent filtering, for having a low mean normalized count, then only the adjusted p value will be set to NA. Description and customization of independent filtering is described below

# %%
DE_scSHM %>% arrange(pval)
# Out:
#      rowname  log2FoldChange lfcSE pval         padj
# 1    PCBP1     2.2105281     NA    1.413830e-41 1.837979e-38
# 2    CTSB     -4.8607318     NA    5.602103e-41 3.641367e-38
# 3    RCSD1    -2.5478516     NA    3.804563e-40 1.648644e-37
# 4    LTB       3.9255661     NA    3.096974e-39 1.006516e-36
# 5    MBD2      2.7357171     NA    4.371826e-30 1.136675e-27
# 6    TCF4      1.5818822     NA    7.094249e-30 1.537087e-27
# 7    UBC      -1.2662843     NA    6.562910e-29 1.218826e-26
# 8    ATP5F1A   1.3808300     NA    9.875949e-29 1.604842e-26
# 9    BMP7      3.3655398     NA    4.837176e-28 6.987032e-26
# 10   ARPC3     1.0091736     NA    1.454459e-27 1.890797e-25
# 11   IGHA1     2.7247643     NA    1.137060e-25 1.343798e-23
# 12   CD81      1.8037406     NA    4.531516e-25 4.909142e-23
# 13   PPP1CC    1.8051008     NA    8.068008e-24 8.068008e-22
# 14   CD74     -0.9780342     NA    1.971269e-23 1.830464e-21
# 15   TXNL1     1.6745129     NA    6.462915e-23 5.601193e-21
# 16   HLA-DPA1 -1.4769216     NA    4.168367e-22 3.310133e-20
# 17   PPP1R14B  2.4056877     NA    4.328636e-22 3.310133e-20
# 18   RALGPS2  -1.8513294     NA    3.126582e-21 2.258087e-19
# 19   PABPN1    1.5753158     NA    1.388078e-20 9.497379e-19
# 20   FAM107B   2.2542409     NA    2.443026e-20 1.587967e-18
# 21   TSC22D3  -1.8332001     NA    4.313329e-20 2.670156e-18
# 22   TSPAN33   2.5081227     NA    4.706594e-20 2.781169e-18
# 23   HLA-DRB1 -1.3634501     NA    8.496040e-20 4.802109e-18
# 24   TCL1A    -1.1588379     NA    1.323300e-19 7.167877e-18
# 25   MAP2K2    2.2154835     NA    1.393765e-19 7.247580e-18
# 26   PABPC1    0.9620160     NA    1.514123e-19 7.570615e-18
# 27   GNB1      2.2159496     NA    3.767554e-19 1.814007e-17
# 28   HLA-DRA  -1.1492751     NA    4.015649e-19 1.864408e-17
# 29   LY86     -1.8799020     NA    8.667129e-19 3.885265e-17
# 30   HLA-DRB5 -1.6332861     NA    2.111160e-18 9.148358e-17
# ⋮    ⋮        ⋮              ⋮     ⋮            ⋮
# 1271 PRMT2    -0.0114511674  NA    0.9562170    0.9780347
# 1272 PPM1G    -0.0096686658  NA    0.9589339    0.9800425
# 1273 RALY     -0.0078825814  NA    0.9610506    0.9808640
# 1274 NDUFB7    0.0089944151  NA    0.9612467    0.9808640
# 1275 SARNP     0.0097265814  NA    0.9626051    0.9814798
# 1276 FIBP     -0.0088871923  NA    0.9638663    0.9819955
# 1277 FNTA      0.0093631380  NA    0.9646401    0.9820142
# 1278 TUBA4A    0.0088029079  NA    0.9665225    0.9831606
# 1279 USP6NL   -0.0078106435  NA    0.9711385    0.9870571
# 1280 RAB1B    -0.0068548451  NA    0.9720215    0.9870571
# 1281 BACH2     0.0075796742  NA    0.9730627    0.9870571
# 1282 IK        0.0067187024  NA    0.9733901    0.9870571
# 1283 HNRNPA0   0.0044353625  NA    0.9761073    0.9890409
# 1284 UBA52    -0.0017644403  NA    0.9819861    0.9942227
# 1285 GTF2I    -0.0037033504  NA    0.9832744    0.9944114
# 1286 ISCU      0.0039757516  NA    0.9837023    0.9944114
# 1287 SNRPD2   -0.0017600050  NA    0.9855637    0.9944694
# 1288 DCTN2    -0.0033465428  NA    0.9859557    0.9944694
# 1289 KHDRBS1  -0.0020469391  NA    0.9868854    0.9944694
# 1290 SYNRG     0.0033556296  NA    0.9872483    0.9944694
# 1291 CLEC2D   -0.0030960726  NA    0.9875846    0.9944694
# 1292 CFL1     -0.0013603349  NA    0.9883901    0.9945102
# 1293 SMS       0.0027377386  NA    0.9896375    0.9949952
# 1294 TOP1      0.0013217370  NA    0.9937024    0.9980921
# 1295 ATP5MC1  -0.0012070747  NA    0.9952306    0.9980921
# 1296 HSPA8     0.0005807130  NA    0.9958385    0.9980921
# 1297 SEM1     -0.0005864778  NA    0.9967063    0.9980921
# 1298 EIF5      0.0007142020  NA    0.9967774    0.9980921
# 1299 SMIM14   -0.0007595241  NA    0.9973243    0.9980921
# 1300 AKR7A2    0.0003547788  NA    0.9986775    0.9986775

# %% [markdown]
# # Pathway analysis

# %% [markdown]
# ### Convert genes names to Entrez Gene

# %%
DE_scSHM$entrez = mapIds(org.Hs.eg.db,
                     keys=DE_scSHM$rowname, 
                     column="ENTREZID",
                     keytype="SYMBOL",
                     multiVals="first")
DE_scSHM$name =   mapIds(org.Hs.eg.db,
                     keys=DE_scSHM$rowname, 
                     column="GENENAME",
                     keytype="SYMBOL",
                     multiVals="first")
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns

# %% [markdown]
# ## Generally Applicable Gene-set Enrichment for Pathway Analysis

# %%
# pathways not related with B cells
unvaluable_pathway <- c("hsa04650 Natural killer cell mediated cytotoxicity","hsa04380 Osteoclast differentiation",
                        "hsa04966 Collecting duct acid secretion","hsa04971 Gastric acid secretion","hsa04914 Progesterone-mediated oocyte maturation",
                        "hsa04720 Long-term potentiation","hsa04916 Melanogenesis", "hsa04260 Cardiac muscle contraction")

# %%
#remove those pathways from the list genes
kegg.sets.hs_filter <- discard(kegg.sets.hs, (names(kegg.sets.hs) %in% unvaluable_pathway ))

# %%
#DE_scSHM_filter <- DE_scSHM %>% filter(padj < 0.05)

# %%
foldchanges = DE_scSHM$log2FoldChange
names(foldchanges) = DE_scSHM_filter$entrez
head(foldchanges)
# Out:
#      29101       2782      11315      10236      55629      10772
# -0.2059678 -0.1118098  0.9111096  2.2159496 -0.2148776  0.3180574

# %%
# Get the results
keggres = gage(foldchanges, gsets=kegg.sets.hs_filter, same.dir=TRUE)

# Look at both up (greater), down (less), and statatistics.
lapply(keggres, head,20)
# Out:
# $greater
#                                                        p.geomean   stat.mean
# hsa04670 Leukocyte transendothelial migration         0.09607417  1.35117704
# hsa04145 Phagosome                                    0.25440628  0.66558260
# hsa04810 Regulation of actin cytoskeleton             0.32806630  0.44865798
# hsa04612 Antigen processing and presentation          0.36899579  0.33744313
# hsa04514 Cell adhesion molecules (CAMs)               0.39362603  0.27286389
# hsa04666 Fc gamma R-mediated phagocytosis             0.42818877  0.18261804
# hsa04062 Chemokine signaling pathway                  0.45351580  0.11827974
# hsa04662 B cell receptor signaling pathway            0.45488265  0.11455466
# hsa04141 Protein processing in endoplasmic reticulum  0.52626641 -0.06646773
# hsa04010 MAPK signaling pathway                       0.56722785 -0.17189734
# hsa04672 Intestinal immune network for IgA production 0.64438589 -0.37619797
# hsa04722 Neurotrophin signaling pathway               0.71701612 -0.58476419
# hsa03013 RNA transport                                0.76626272 -0.73992049
# hsa04640 Hematopoietic cell lineage                   0.83168863 -0.99248488
# hsa04144 Endocytosis                                  0.84966526 -1.06708178
# hsa03040 Spliceosome                                  0.87269011 -1.15427262
# hsa00190 Oxidative phosphorylation                    0.97278952 -1.97422114
# hsa00232 Caffeine metabolism                                  NA         NaN
# hsa00983 Drug metabolism - other enzymes                      NA         NaN
# hsa00230 Purine metabolism                                    NA         NaN
#                                                            p.val     q.val
# hsa04670 Leukocyte transendothelial migration         0.09607417 0.9272332
# hsa04145 Phagosome                                    0.25440628 0.9272332
# hsa04810 Regulation of actin cytoskeleton             0.32806630 0.9272332
# hsa04612 Antigen processing and presentation          0.36899579 0.9272332
# hsa04514 Cell adhesion molecules (CAMs)               0.39362603 0.9272332
# hsa04666 Fc gamma R-mediated phagocytosis             0.42818877 0.9272332
# hsa04062 Chemokine signaling pathway                  0.45351580 0.9272332
# hsa04662 B cell receptor signaling pathway            0.45488265 0.9272332
# hsa04141 Protein processing in endoplasmic reticulum  0.52626641 0.9272332
# hsa04010 MAPK signaling pathway                       0.56722785 0.9272332
# hsa04672 Intestinal immune network for IgA production 0.64438589 0.9272332
# hsa04722 Neurotrophin signaling pathway               0.71701612 0.9272332
# hsa03013 RNA transport                                0.76626272 0.9272332
# hsa04640 Hematopoietic cell lineage                   0.83168863 0.9272332
# hsa04144 Endocytosis                                  0.84966526 0.9272332
# hsa03040 Spliceosome                                  0.87269011 0.9272332
# hsa00190 Oxidative phosphorylation                    0.97278952 0.9727895
# hsa00232 Caffeine metabolism                                  NA        NA
# hsa00983 Drug metabolism - other enzymes                      NA        NA
# hsa00230 Purine metabolism                                    NA        NA
#                                                       set.size       exp1
# hsa04670 Leukocyte transendothelial migration               12 0.09607417
# hsa04145 Phagosome                                          26 0.25440628
# hsa04810 Regulation of actin cytoskeleton                   21 0.32806630
# hsa04612 Antigen processing and presentation                17 0.36899579
# hsa04514 Cell adhesion molecules (CAMs)                     15 0.39362603
# hsa04666 Fc gamma R-mediated phagocytosis                   16 0.42818877
# hsa04062 Chemokine signaling pathway                        11 0.45351580
# hsa04662 B cell receptor signaling pathway                  13 0.45488265
# hsa04141 Protein processing in endoplasmic reticulum        16 0.52626641
# hsa04010 MAPK signaling pathway                             10 0.56722785
# hsa04672 Intestinal immune network for IgA production       13 0.64438589
# hsa04722 Neurotrophin signaling pathway                     10 0.71701612
# hsa03013 RNA transport                                      16 0.76626272
# hsa04640 Hematopoietic cell lineage                         10 0.83168863
# hsa04144 Endocytosis                                        11 0.84966526
# hsa03040 Spliceosome                                        23 0.87269011
# hsa00190 Oxidative phosphorylation                          27 0.97278952
# hsa00232 Caffeine metabolism                                 0         NA
# hsa00983 Drug metabolism - other enzymes                     0         NA
# hsa00230 Purine metabolism                                   7         NA
#
# $less
#                                                        p.geomean   stat.mean
# hsa00190 Oxidative phosphorylation                    0.02721048 -1.97422114
# hsa03040 Spliceosome                                  0.12730989 -1.15427262
# hsa04144 Endocytosis                                  0.15033474 -1.06708178
# hsa04640 Hematopoietic cell lineage                   0.16831137 -0.99248488
# hsa03013 RNA transport                                0.23373728 -0.73992049
# hsa04722 Neurotrophin signaling pathway               0.28298388 -0.58476419
# hsa04672 Intestinal immune network for IgA production 0.35561411 -0.37619797
# hsa04010 MAPK signaling pathway                       0.43277215 -0.17189734
# hsa04141 Protein processing in endoplasmic reticulum  0.47373359 -0.06646773
# hsa04662 B cell receptor signaling pathway            0.54511735  0.11455466
# hsa04062 Chemokine signaling pathway                  0.54648420  0.11827974
# hsa04666 Fc gamma R-mediated phagocytosis             0.57181123  0.18261804
# hsa04514 Cell adhesion molecules (CAMs)               0.60637397  0.27286389
# hsa04612 Antigen processing and presentation          0.63100421  0.33744313
# hsa04810 Regulation of actin cytoskeleton             0.67193370  0.44865798
# hsa04145 Phagosome                                    0.74559372  0.66558260
# hsa04670 Leukocyte transendothelial migration         0.90392583  1.35117704
# hsa00232 Caffeine metabolism                                  NA         NaN
# hsa00983 Drug metabolism - other enzymes                      NA         NaN
# hsa00230 Purine metabolism                                    NA         NaN
#                                                            p.val     q.val
# hsa00190 Oxidative phosphorylation                    0.02721048 0.4625782
# hsa03040 Spliceosome                                  0.12730989 0.7153233
# hsa04144 Endocytosis                                  0.15033474 0.7153233
# hsa04640 Hematopoietic cell lineage                   0.16831137 0.7153233
# hsa03013 RNA transport                                0.23373728 0.7615249
# hsa04722 Neurotrophin signaling pathway               0.28298388 0.7615249
# hsa04672 Intestinal immune network for IgA production 0.35561411 0.7615249
# hsa04010 MAPK signaling pathway                       0.43277215 0.7615249
# hsa04141 Protein processing in endoplasmic reticulum  0.47373359 0.7615249
# hsa04662 B cell receptor signaling pathway            0.54511735 0.7615249
# hsa04062 Chemokine signaling pathway                  0.54648420 0.7615249
# hsa04666 Fc gamma R-mediated phagocytosis             0.57181123 0.7615249
# hsa04514 Cell adhesion molecules (CAMs)               0.60637397 0.7615249
# hsa04612 Antigen processing and presentation          0.63100421 0.7615249
# hsa04810 Regulation of actin cytoskeleton             0.67193370 0.7615249
# hsa04145 Phagosome                                    0.74559372 0.7921933
# hsa04670 Leukocyte transendothelial migration         0.90392583 0.9039258
# hsa00232 Caffeine metabolism                                  NA        NA
# hsa00983 Drug metabolism - other enzymes                      NA        NA
# hsa00230 Purine metabolism                                    NA        NA
#                                                       set.size       exp1
# hsa00190 Oxidative phosphorylation                          27 0.02721048
# hsa03040 Spliceosome                                        23 0.12730989
# hsa04144 Endocytosis                                        11 0.15033474
# hsa04640 Hematopoietic cell lineage                         10 0.16831137
# hsa03013 RNA transport                                      16 0.23373728
# hsa04722 Neurotrophin signaling pathway                     10 0.28298388
# hsa04672 Intestinal immune network for IgA production       13 0.35561411
# hsa04010 MAPK signaling pathway                             10 0.43277215
# hsa04141 Protein processing in endoplasmic reticulum        16 0.47373359
# hsa04662 B cell receptor signaling pathway                  13 0.54511735
# hsa04062 Chemokine signaling pathway                        11 0.54648420
# hsa04666 Fc gamma R-mediated phagocytosis                   16 0.57181123
# hsa04514 Cell adhesion molecules (CAMs)                     15 0.60637397
# hsa04612 Antigen processing and presentation                17 0.63100421
# hsa04810 Regulation of actin cytoskeleton                   21 0.67193370
# hsa04145 Phagosome                                          26 0.74559372
# hsa04670 Leukocyte transendothelial migration               12 0.90392583
# hsa00232 Caffeine metabolism                                 0         NA
# hsa00983 Drug metabolism - other enzymes                     0         NA
# hsa00230 Purine metabolism                                   7         NA
#
# $stats
#                                                         stat.mean        exp1
# hsa04670 Leukocyte transendothelial migration          1.35117704  1.35117704
# hsa04145 Phagosome                                     0.66558260  0.66558260
# hsa04810 Regulation of actin cytoskeleton              0.44865798  0.44865798
# hsa04612 Antigen processing and presentation           0.33744313  0.33744313
# hsa04514 Cell adhesion molecules (CAMs)                0.27286389  0.27286389
# hsa04666 Fc gamma R-mediated phagocytosis              0.18261804  0.18261804
# hsa04062 Chemokine signaling pathway                   0.11827974  0.11827974
# hsa04662 B cell receptor signaling pathway             0.11455466  0.11455466
# hsa04141 Protein processing in endoplasmic reticulum  -0.06646773 -0.06646773
# hsa04010 MAPK signaling pathway                       -0.17189734 -0.17189734
# hsa04672 Intestinal immune network for IgA production -0.37619797 -0.37619797
# hsa04722 Neurotrophin signaling pathway               -0.58476419 -0.58476419
# hsa03013 RNA transport                                -0.73992049 -0.73992049
# hsa04640 Hematopoietic cell lineage                   -0.99248488 -0.99248488
# hsa04144 Endocytosis                                  -1.06708178 -1.06708178
# hsa03040 Spliceosome                                  -1.15427262 -1.15427262
# hsa00190 Oxidative phosphorylation                    -1.97422114 -1.97422114
# hsa00232 Caffeine metabolism                                  NaN          NA
# hsa00983 Drug metabolism - other enzymes                      NaN          NA
# hsa00230 Purine metabolism                                    NaN          NA

# %%
# Get the pathways
keggrespathways = data.frame(id=rownames(keggres$greater), keggres$greater) %>% 
  tbl_df() %>% 
  filter(row_number()<=5) %>% 
  .$id %>% 
  as.character()
keggrespathways

# %%
# Get the IDs.
keggresids = substr(keggrespathways, start=1, stop=8)
keggresids

# %%
# Define plotting function for applying later
plot_pathway = function(pid) pathview(gene.data=foldchanges, pathway.id=pid, species="hsa", new.signature=FALSE)

# plot multiple pathways (plots saved to disk and returns a throwaway list object)
tmp = sapply(keggresids, function(pid) pathview(gene.data=foldchanges, pathway.id=pid, species="hsa")) #kegg.native = F, same.layer = F

# %%
write.csv(DE_scSHM, "output/DE_scSHM.csv")

# %% [markdown]
# # test

# %%
    # extract count table and subset for cells in colData
    cts <-
      FL.integrated@assays$RNA@data  %>%
      as.matrix()%>% #add step
      as.data.frame() %>%
#      dplyr::select( rownames( cell1) ) %>%
      rownames_to_column( var = "geneName" )
    
    # remove RPL, RPS and MT- genes
    cts <-
      cts %>% 
      filter(geneName %like% "JUND" )

# %%
ctsd <- ctsd %>% as.data.frame()
# Out:
# Error in h(simpleError(msg, call)): error in evaluating the argument 'x' in selecting a method for function 'as.data.frame': object 'ctsd' not found
# Traceback:
#
# 1. ctsd %>% as.data.frame()
# 2. as.data.frame(.)
# 3. .handleSimpleError(function (cond)
#  . .Internal(C_tryCatchHelper(addr, 1L, cond)), "object 'ctsd' not found",
#  .     base::quote(as.data.frame(.)))
# 4. h(simpleError(msg, call))

# %%
head(ctsd)

# %%
cells1

# %%
rownames(ctsd)

# %%
head(cells1)

# %%
head(ctsd)

# %%
DF.new <-  ctsd[row.names(ctsd) %in% cells1,]

# %%
head(DF.new)

# %%
colnames(DF.new) <- c("expression")

# %%
DF.new2 <- DF.new %>% rownames_to_column( var = "cell" ) %>% mutate(gene="JUND",expression = as.numeric(expression))

# %%
head(DF.new2)

# %%
# Basic violin plot
ggplot(DF.new2, aes(x=gene, y=expression)) + 
  geom_violin(trim=FALSE, fill="gray")+
  labs(title="Plot of Expression gene x",x="Gene)", y = "Expression")+
  geom_boxplot(width=0.3)+
  theme_classic()
# Change color by groups
dp <- ggplot(DF.new2, aes(x=gene, y=expression)) + 
  geom_violin(trim=FALSE)+
  geom_boxplot(width=0.1, fill="white")+
  labs(title="Plot of Expression gene x",x="Gene)", y = "Expression")
dp + theme_classic() +
geom_dotplot(binaxis='y', stackdir='center', dotsize=0.1)

# %%
# Basic violin plot
ggplot(DF.new2, aes(x=gene, y=expression)) + 
  geom_violin(trim=FALSE, fill="gray")+
  labs(title="Plot of Expression gene x",x="Gene)", y = "Expression")+
  geom_boxplot(width=0.3)+
  theme_classic()
# Change color by groups
dp <- ggplot(DF.new2, aes(x=gene, y=expression)) + 
  geom_violin(trim=FALSE)+
  geom_boxplot(width=0.3, fill="white")+
  labs(title="Plot of Expression gene x",x="Gene)", y = "Expression")
dp + theme_classic() +
geom_dotplot(binaxis='y', stackdir='center', dotsize=0.5)
